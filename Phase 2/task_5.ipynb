# %%
from utils import *
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
fd_collection = getCollection("team_5_mwdb_phase_2", "fd_collection")

# %%
selected_feature_model = valid_feature_models[
    str(input("Enter feature model - one of " + str(list(valid_feature_models.keys()))))
]

k = int(input("Enter value of k: "))
if k < 1:
    raise ValueError("k should be a positive integer")

selected_dim_reduction_method = str(
    input(
        "Enter dimensionality reduction method - one of "
        + str(list(valid_dim_reduction_methods.keys()))
    )
)

label_sim_matrix = find_label_label_similarity(fd_collection,selected_feature_model)

extract_latent_semantics_from_sim_matrix(
    label_sim_matrix,
    selected_feature_model,
    "label",
    k,
    selected_dim_reduction_method,
    top_images=10,
)
# Out:
# Applying kmeans on the given similarity matrix to get 10 latent semantics (showing only top 10 label-weight pairs for each latent semantic)...
# Initialized centroids
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iter 11 - Converged
# Latent semantic no. 0
# label	84	-	Weight	16.953715652557495
# label	34	-	Weight	17.25164883471016
# label	1	-	Weight	17.379970016799952
# label	72	-	Weight	17.439397073433092
# label	32	-	Weight	17.447297173030393
# label	31	-	Weight	17.448932606262144
# label	40	-	Weight	17.561159943630802
# label	79	-	Weight	17.572813876633166
# label	5	-	Weight	17.721278660592027
# label	56	-	Weight	17.731177291838822
# Latent semantic no. 1
# label	84	-	Weight	19.27643729221191
# label	5	-	Weight	19.449814613173483
# label	32	-	Weight	19.684592406270944
# label	63	-	Weight	19.911988624963808
# label	79	-	Weight	19.930151237028223
# label	38	-	Weight	19.948477661871497
# label	89	-	Weight	19.965086791647906
# label	94	-	Weight	19.990956583854018
# label	72	-	Weight	19.99680017871235
# label	45	-	Weight	20.058898160614795
# Latent semantic no. 2
# label	0	-	Weight	nan
# label	1	-	Weight	nan
# label	2	-	Weight	nan
# label	3	-	Weight	nan
# label	4	-	Weight	nan
# label	5	-	Weight	nan
# label	6	-	Weight	nan
# label	7	-	Weight	nan
# label	8	-	Weight	nan
# label	9	-	Weight	nan
# Latent semantic no. 3
# label	0	-	Weight	nan
# label	1	-	Weight	nan
# label	2	-	Weight	nan
# label	3	-	Weight	nan
# label	4	-	Weight	nan
# label	5	-	Weight	nan
# label	6	-	Weight	nan
# label	7	-	Weight	nan
# label	8	-	Weight	nan
# label	9	-	Weight	nan
# Latent semantic no. 4
# label	32	-	Weight	18.607843379925203
# label	89	-	Weight	18.671771165930238
# label	84	-	Weight	18.83858895833768
# label	79	-	Weight	18.84775924713071
# label	55	-	Weight	18.88614269359777
# label	34	-	Weight	18.891433443455583
# label	11	-	Weight	19.034715149675442
# label	63	-	Weight	19.042445031693624
# label	5	-	Weight	19.075471660855772
# label	59	-	Weight	19.096232354525338
# Latent semantic no. 5
# label	88	-	Weight	17.332684081151356
# label	100	-	Weight	17.414638052725692
# label	89	-	Weight	17.64193670680817
# label	46	-	Weight	17.663677856892257
# label	5	-	Weight	17.750606635854105
# label	11	-	Weight	17.921812162626082
# label	17	-	Weight	17.99728875058849
# label	64	-	Weight	18.20535869665654
# label	84	-	Weight	18.280826365832894
# label	59	-	Weight	18.48939095974247
# Latent semantic no. 6
# label	0	-	Weight	nan
# label	1	-	Weight	nan
# label	2	-	Weight	nan
# label	3	-	Weight	nan
# label	4	-	Weight	nan
# label	5	-	Weight	nan
# label	6	-	Weight	nan
# label	7	-	Weight	nan
# label	8	-	Weight	nan
# label	9	-	Weight	nan
# Latent semantic no. 7
# label	59	-	Weight	19.676597202857955
# label	72	-	Weight	19.687934144875545
# label	89	-	Weight	19.830805124280474
# label	90	-	Weight	20.021426354120276
# label	77	-	Weight	20.05776182294002
# label	34	-	Weight	20.058245159709028
# label	70	-	Weight	20.117786048649382
# label	68	-	Weight	20.139598145778074
# label	88	-	Weight	20.185751240083068
# label	38	-	Weight	20.208902223231863
# Latent semantic no. 8
# label	0	-	Weight	nan
# label	1	-	Weight	nan
# label	2	-	Weight	nan
# label	3	-	Weight	nan
# label	4	-	Weight	nan
# label	5	-	Weight	nan
# label	6	-	Weight	nan
# label	7	-	Weight	nan
# label	8	-	Weight	nan
# label	9	-	Weight	nan
# Latent semantic no. 9
# label	0	-	Weight	nan
# label	1	-	Weight	nan
# label	2	-	Weight	nan
# label	3	-	Weight	nan
# label	4	-	Weight	nan
# label	5	-	Weight	nan
# label	6	-	Weight	nan
# label	7	-	Weight	nan
# label	8	-	Weight	nan
# label	9	-	Weight	nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\Fall 23\CSE 515 - Multimedia and web databases\CSE515_MWDB_Project\Phase 2\task_5.ipynb Cell 3 line 1
#       <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> selected_dim_reduction_method = str(
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>     input(
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a>         "Enter dimensionality reduction method - one of "
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>         + str(list(valid_dim_reduction_methods.keys()))
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a>     )
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a> )
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> label_sim_matrix = find_label_label_similarity(fd_collection,selected_feature_model)
# ---> <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a> extract_latent_semantics_from_sim_matrix(
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a>     label_sim_matrix,
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a>     selected_feature_model,
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=20'>21</a>     "label",
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=21'>22</a>     k,
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=22'>23</a>     selected_dim_reduction_method,
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=23'>24</a>     top_images=10,
#      <a href='vscode-notebook-cell:/e%3A/Fall%2023/CSE%20515%20-%20Multimedia%20and%20web%20databases/CSE515_MWDB_Project/Phase%202/task_5.ipynb#W6sZmlsZQ%3D%3D?line=24'>25</a> )
#
# File e:\Fall 23\CSE 515 - Multimedia and web databases\CSE515_MWDB_Project\Phase 2\utils.py:1193, in extract_latent_semantics_from_sim_matrix(sim_matrix, feature_model, sim_type, k, dim_reduction_method, top_images)
#    1187 for label in range(num_labels):
#    1188     # get representative vectors for the label
#    1189     label_mean_vectors.append(
#    1190         calculate_label_representatives(fd_collection, label, feature_model)
#    1191     )
# -> 1193 label_sim_matrix = np.zeros((num_labels, num_labels))
#    1195 # Calculate half and fill the other
#    1196 for i in range(num_labels):
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:432, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
# --> 432     yield from _iterencode_dict(o, _current_indent_level)
#     433 else:
#     434     if markers is not None:
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:326, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     324         else:
#     325             chunks = _iterencode(value, _current_indent_level)
# --> 326         yield from chunks
#     327 if newline_indent is not None:
#     328     _current_indent_level -= 1
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type ndarray is not JSON serializable
